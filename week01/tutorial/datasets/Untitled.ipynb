# %%
import pandas as pd

r = pd.read_csv('recipes.csv',delimiter=';')
r.head()
# Out:
#    id                                                url
# 0   0  https://ricette.giallozafferano.it/Pancakes-al...  \
# 1   1   https://ricette.giallozafferano.it/Tiramisu.html
# 2   2  https://ricette.giallozafferano.it/Crepes-dolc...
# 3   3  https://ricette.giallozafferano.it/Spaghetti-a...
# 4   4  https://ricette.giallozafferano.it/Impasto-per...
#
#                                    title         cost      category
# 0             Pancakes with dacere syrup  Molto basso         Dolci  \
# 1                               Tiramisu        Medio         Dolci
# 2  Sweet and salty crepes (basic recipe)        Basso         Dolci
# 3                    Spaghetti carbonara        Basso  Primi piatti
# 4                        Pasta for pizza  Molto basso     Lievitati
#
#                                             imageURL
# 0  https://www.giallozafferano.it/images/ricette/...  \
# 1  https://www.giallozafferano.it/images/ricette/...
# ...

# %%
b = pd.read_csv('books.csv')
b.head()
# Out:
#    Unnamed: 0  bookID                                 title      authors
# 0           0      21  A Short History of Nearly Everything  Bill Bryson  \
# 1           1      21  A Short History of Nearly Everything  Bill Bryson
# 2           2    3870  A Short History of Nearly Everything  Bill Bryson
# 3           3    3870  A Short History of Nearly Everything  Bill Bryson
# 4           4      22           Bill Bryson's African Diary  Bill Bryson
#
#    average_rating        isbn         isbn13 language_code    num_pages
# 0            4.21  076790818X  9780767908184           eng          544  \
# 1            4.21  076790818X  9780767908184           eng          544
# 2            4.21  0767923227  9780767923224           eng          624
# 3            4.21  0767923227  9780767923224           eng          624
# 4            3.44  0767915062  9780767915069           eng           55
#
#    ratings_count  text_reviews_count publication_date       publisher
# ...

# %%
n = pd.read_csv('news.csv')
n.head()
# Out:
#    Unnamed: 0           source_id         source_name              author
# 0           0             reuters             Reuters   Reuters Editorial  \
# 1           1     the-irish-times     The Irish Times  Eoin Burke-Kennedy
# 2           2     the-irish-times     The Irish Times   Deirdre McQuillan
# 3           3  al-jazeera-english  Al Jazeera English          Al Jazeera
# 4           4            bbc-news            BBC News            BBC News
#
#                                                title
# 0  NTSB says Autopilot engaged in 2018 California...  \
# 1       Unemployment falls to post-crash low of 5.2%
# 2  Louise Kennedy AW2019: Long coats, sparkling t...
# 3  North Korean footballer Han joins Italian gian...
# 4  UK government lawyer says proroguing parliamen...
#
#                                          description
# 0  The National Transportation Safety Board said ...  \
# 1  Latest monthly figures reflect continued growt...
# ...
